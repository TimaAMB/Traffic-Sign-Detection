# %%
# !pip install ultralytics
# !pip install ultralytics==8.0.196
from IPython import display

import ultralytics

# %%
# %cd {"/content/drive/MyDrive"}

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2v6OpGXoevarhj5VBGV3")
project = rf.workspace("college-g19gz").project("road-sign-detector-image-dataset")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive'
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Road-Sign-Detector-Image-Dataset-1 in yolov5pytorch:: 100%|██████████| 6972/6972 [00:01<00:00, 3828.54it/s]

# %%
# !yolo task=detect mode=train model=yolov5s.pt data="/content/Road-Sign-Detector-Image-Dataset-1/data.yaml" epochs=45 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 17.7M/17.7M [00:00<00:00, 221MB/s]
# New https://pypi.org/project/ultralytics/8.2.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# Load a model
#model = YOLO('yolov8n.pt')  # load an official model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # load a custom model
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5s summary (fused): 193 layers, 9121985 parameters, 0 gradients, 23.9 GFLOPs
# val: Scanning /content/Road-Sign-Detector-Image-Dataset-1/valid/labels.cache... 288 images, 0 backgrounds, 0 corrupt: 100%|██████████| 288/288 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:07<00:00,  2.40it/s]
#                    all        288        305       0.93      0.919      0.947      0.712
#                      -        288         20          1      0.969      0.995      0.905
# - Auto-orientation of pixel data -with EXIF-orientation stripping-        288          8      0.982          1      0.995      0.543
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Provide the path to your image file
image_path = '/content/runs/detect/train/confusion_matrix.png'

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Provide the path to your image file
image_path = '/content/runs/detect/train/confusion_matrix_normalized.png'

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Provide the path to your image file
image_path = '/content/runs/detect/train/results.png'

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Provide the path to your image file
image_path = '/content/runs/detect/train/train_batch0.jpg'

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Provide the path to your image file
image_path = '/content/runs/detect/train/val_batch0_labels.jpg'

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Provide the path to your image file
image_path = '/content/runs/detect/train/val_batch1_labels.jpg'

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.show()
