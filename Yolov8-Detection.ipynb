# %%
# !pip install ultralytics
# !pip install ultralytics==8.0.196
from IPython import display

import ultralytics

# %%
# %cd {"/content/drive/MyDrive"}

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2v6OpGXoevarhj5VBGV3")
project = rf.workspace("college-g19gz").project("road-sign-detector-image-dataset")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive'
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Road-Sign-Detector-Image-Dataset-1 in yolov8:: 100%|██████████| 6972/6972 [00:02<00:00, 2764.04it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data="/content/Road-Sign-Detector-Image-Dataset-1/data.yaml" epochs=32 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 360MB/s]
# New https://pypi.org/project/ultralytics/8.2.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
# Load a model
#model = YOLO('yolov8n.pt')  # load an official model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # load a custom model
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25855393 parameters, 0 gradients, 78.8 GFLOPs
# val: Scanning /content/Road-Sign-Detector-Image-Dataset-1/valid/labels.cache... 288 images, 0 backgrounds, 0 corrupt: 100%|██████████| 288/288 [00:00<?, ?it/s]
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:10<00:00,  1.76it/s]
#                    all        288        305      0.916       0.94      0.958      0.721
#                      -        288         20      0.982          1      0.995      0.901
# - Auto-orientation of pixel data -with EXIF-orientation stripping-        288          8       0.86          1      0.995      0.593
# ...
